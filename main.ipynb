# %% [markdown]
# # COM731 Hotel Booking Analysis System
# Main program for the COM731 software project.

# %%
from data_loader import load_csv_as_list, load_csv_as_dataframe
from user_interface import main_menu

# %%
file_path = input('Enter the CSV file name or file path [hotel_booking.csv]: ').strip()
if not file_path:
    file_path = 'hotel_booking.csv'
header, list_data = load_csv_as_list(file_path)
dataframe = load_csv_as_dataframe(file_path)

# %%
if header is not None and list_data is not None and dataframe is not None:
    main_menu(header, list_data, dataframe)
else:
    print('The software cannot start because the dataset was not loaded.')
